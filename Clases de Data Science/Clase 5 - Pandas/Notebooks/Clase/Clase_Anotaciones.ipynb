# %%
#importamos librerias
import pandas as pd

# %%
#probamos creando uno a mano
#data = pd.Series([0.1,0.2,0.3], index =["Hola","Chao","hola"])
#data

# %%
#data.index

# %%
#Cargamos el archivo
filename ='arbolado-publico-lineal-2017-2018.csv'
data = pd.read_csv(filename)
# Out:
# C:\Users\TZ182CG\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
# 4 -58.380710 -34.591548        31337     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1  Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 2             Arroyo        800.0       848.0               ARROYO 848
# 3             Arroyo        900.0       932.0               ARROYO 932
# 4             Arroyo        900.0       932.0               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# ...

# %%
data.tail()
# Out:
#         long  lat nro_registro tipo_activ  comuna manzana calle_nombre  \
# 370175   NaN  NaN       546140    Lineal       15     919      Guevara
# 370176   NaN  NaN       546141    Lineal       15     919      Guevara
# 370177   NaN  NaN       546142    Lineal       15     919      Guevara
# 370178   NaN  NaN       546143    Lineal       15     919      Guevara
# 370179   NaN  NaN       546144    Lineal       15     919      Guevara
#
#        calle_altura calle_chapa direccion_normalizada ubicacion  \
# 370175       1000.0      1000.0                   NaN       LD3
# 370176       1000.0      1000.0                   NaN       LD4
# 370177       1000.0      1000.0                   NaN       LD5
# 370178       1000.0      1000.0                   NaN       LD6
# 370179       1000.0      1000.0                   NaN       LD7
#
#        nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# 370175    Ceiba speciosa         3.3         Ocupada            Regular
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370180 entries, 0 to 370179
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   long                   354838 non-null  float64
#  1   lat                    354838 non-null  float64
#  2   nro_registro           370180 non-null  object
#  3   tipo_activ             370180 non-null  object
#  4   comuna                 370180 non-null  int64
#  5   manzana                224140 non-null  object
#  6   calle_nombre           370087 non-null  object
#  7   calle_altura           364677 non-null  object
#  8   calle_chapa            363721 non-null  object
#  9   direccion_normalizada  355941 non-null  object
#  10  ubicacion              361884 non-null  object
#  11  nombre_cientifico      370180 non-null  object
#  12  ancho_acera            367083 non-null  object
#  13  estado_plantera        370180 non-null  object
# ...

# %%
data.describe()
# Out:
#                 long            lat         comuna  diametro_altura_pecho  \
# count  354838.000000  354838.000000  370180.000000          369894.000000
# mean      -58.458791     -34.612473       9.143735              31.986864
# std         0.041514       0.033695       3.876242              21.267623
# min       -58.530458     -34.697333       1.000000               0.000000
# 25%       -58.491269     -34.637834       6.000000              17.000000
# 50%       -58.465865     -34.615023      10.000000              29.000000
# 75%       -58.428583     -34.586580      12.000000              43.000000
# max       -58.354003     -34.535972      15.000000             199.000000
#
#         altura_arbol
# count  365858.000000
# mean        9.036132
# std         4.894625
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        12.000000
# max        40.000000

# %%
data.columns
# Out:
# Index(['long', 'lat', 'nro_registro', 'tipo_activ', 'comuna', 'manzana',
#        'calle_nombre', 'calle_altura', 'calle_chapa', 'direccion_normalizada',
#        'ubicacion', 'nombre_cientifico', 'ancho_acera', 'estado_plantera',
#        'ubicacion_plantera', 'nivel_plantera', 'diametro_altura_pecho',
#        'altura_arbol'],
#       dtype='object')

# %%
print(data.head())
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
# 4 -58.380710 -34.591548        31337     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1  Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 2             Arroyo        800.0       848.0               ARROYO 848
# 3             Arroyo        900.0       932.0               ARROYO 932
# 4             Arroyo        900.0       932.0               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# ...

# %%
display(data.head())
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
# 4 -58.380710 -34.591548        31337     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1  Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 2             Arroyo        800.0       848.0               ARROYO 848
# 3             Arroyo        900.0       932.0               ARROYO 932
# 4             Arroyo        900.0       932.0               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# ...

# %%
for column_name in data.columns:
    print(f'Informacion de la columna {column_name}')
    display (data[column_name].describe())
    print('\n')
# Out:
# Informacion de la columna long
# count    354838.000000
# mean        -58.458791
# std           0.041514
# min         -58.530458
# 25%         -58.491269
# 50%         -58.465865
# 75%         -58.428583
# max         -58.354003
# Name: long, dtype: float64
# Informacion de la columna lat
# count    354838.000000
# mean        -34.612473
# std           0.033695
# min         -34.697333
# 25%         -34.637834
# 50%         -34.615023
# 75%         -34.586580
# max         -34.535972
# Name: lat, dtype: float64
# Informacion de la columna nro_registro
# count     370180
# unique    370180
# top        26779
# freq           1
# Name: nro_registro, dtype: int64
# Informacion de la columna tipo_activ
# count     370180
# unique         6
# top       Lineal
# freq      365629
# Name: tipo_activ, dtype: object
# Informacion de la columna comuna
# count    370180.000000
# mean          9.143735
# std           3.876242
# min           1.000000
# 25%           6.000000
# ...

# %%
#¿donde estan los arboles?
import seaborn as sns

# %%
sns.scatterplot(data = data, x ='long', y = 'lat', hue ='comuna')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>
# C:\Users\TZ182CG\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#haciendo muestreo
sns.scatterplot(data = data.sample(3000), x ='long', y = 'lat', hue ='comuna')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#filtrando
mascara = data['comuna']==11
sns.scatterplot(data = data[mascara], x ='long', y = 'lat', hue ='comuna')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#filtrando
mascara = data['comuna']==12
sns.scatterplot(data = data[mascara], x ='long', y = 'lat', hue ='comuna')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#filtrando
mascara = data['comuna']<5
sns.scatterplot(data = data[mascara], x ='long', y = 'lat', hue ='comuna')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#filtrando
mascara = data['comuna']>5
sns.scatterplot(data = data[mascara], x ='long', y = 'lat', hue ='comuna')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>
# C:\Users\TZ182CG\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#especies de arboles en la ciudad
data['comuna'].value_counts()
# Out:
# 12    38818
# 11    37340
# 9     36405
# 10    33421
# 4     32346
# 15    29587
# 13    28287
# 7     25608
# 14    22417
# 8     21978
# 6     15591
# 5     15224
# 3     13320
# 1     12723
# 2      7115
# Name: comuna, dtype: int64

# %%
data.shape
# Out:
# (370180, 18)

# %%
#porcentaje de arboles en la ciudad
data['comuna'].value_counts()/data.shape[0]*100
# Out:
# 12    10.486250
# 11    10.086985
# 9      9.834405
# 10     9.028311
# 4      8.737911
# 15     7.992598
# 13     7.641418
# 7      6.917716
# 14     6.055703
# 8      5.937112
# 6      4.211735
# 5      4.112594
# 3      3.598250
# 1      3.436977
# 2      1.922038
# Name: comuna, dtype: float64

# %%
#como se donde faltan datos
data.isna().sum()
# Out:
# long                      15342
# lat                       15342
# nro_registro                  0
# tipo_activ                    0
# comuna                        0
# manzana                  146040
# calle_nombre                 93
# calle_altura               5503
# calle_chapa                6459
# direccion_normalizada     14239
# ubicacion                  8296
# nombre_cientifico             0
# ancho_acera                3097
# estado_plantera               0
# ubicacion_plantera         1404
# nivel_plantera             1352
# diametro_altura_pecho       286
# altura_arbol               4322
# dtype: int64

# %%
data.iloc[4]
# Out:
# long                                 -58.38071
# lat                                 -34.591548
# nro_registro                             31337
# tipo_activ                              Lineal
# comuna                                       1
# manzana                                    NaN
# calle_nombre                            Arroyo
# calle_altura                             900.0
# calle_chapa                              932.0
# direccion_normalizada               ARROYO 932
# ubicacion                                   LA
# nombre_cientifico        Jacaranda mimosifolia
# ancho_acera                                NaN
# estado_plantera                        Ocupada
# ubicacion_plantera                     Regular
# nivel_plantera                         A nivel
# diametro_altura_pecho                     13.0
# altura_arbol                               8.0
# Name: 4, dtype: object

# %%
data.iloc[3:5]
# Out:
#        long        lat nro_registro tipo_activ  comuna manzana calle_nombre  \
# 3 -58.38071 -34.591548        31336     Lineal       1     NaN       Arroyo
# 4 -58.38071 -34.591548        31337     Lineal       1     NaN       Arroyo
#
#   calle_altura calle_chapa direccion_normalizada ubicacion  \
# 3        900.0       932.0            ARROYO 932        LD
# 4        900.0       932.0            ARROYO 932        LA
#
#         nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# 3  Fraxinus pennsylvanica         NaN         Ocupada            Regular
# 4   Jacaranda mimosifolia         NaN         Ocupada            Regular
#
#   nivel_plantera  diametro_altura_pecho  altura_arbol
# 3        A nivel                    9.0          29.0
# 4        A nivel                   13.0           8.0

# %%
data.iloc[3:9:2]
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana calle_nombre  \
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN       Arroyo
# 5 -58.381043 -34.591584        31344     Lineal       1     NaN       Arroyo
# 7 -58.373356 -34.594871        31864     Lineal       1     NaN  Reconquista
#
#   calle_altura calle_chapa direccion_normalizada  ubicacion  \
# 3        900.0       932.0            ARROYO 932         LD
# 5        900.0       970.0            ARROYO 970     Exacta
# 7       1100.0      1126.0      RECONQUISTA 1126  En frente
#
#         nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# 3  Fraxinus pennsylvanica         NaN         Ocupada            Regular
# 5  Fraxinus pennsylvanica         3.5         Ocupada            Regular
# 7   Jacaranda mimosifolia         NaN         Ocupada                NaN
#
#   nivel_plantera  diametro_altura_pecho  altura_arbol
# 3        A nivel                    9.0          29.0
# ...

# %%
data.loc[:3] #toma el ult. numero porque lo considera etiqueta
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1  Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 2             Arroyo        800.0       848.0               ARROYO 848
# 3             Arroyo        900.0       932.0               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# 1    Exacta      Peltophorum dubium         4.5         Ocupada
# 2    Exacta  Fraxinus pennsylvanica           4         Ocupada
# ...

# %%
data.index = data["comuna"]
data.head()
# Out:
#              long        lat nro_registro tipo_activ  comuna manzana  \
# comuna
# 1      -58.378563 -34.594902        26779     Lineal       1     NaN
# 1      -58.381532 -34.592319        30887     Lineal       1     NaN
# 1      -58.379103 -34.591939        30904     Lineal       1     NaN
# 1      -58.380710 -34.591548        31336     Lineal       1     NaN
# 1      -58.380710 -34.591548        31337     Lineal       1     NaN
#
#              calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# comuna
# 1               Esmeralda       1000.0      1120.0           ESMERALDA 1120
# 1       Pellegrini Carlos       1300.0      1345.0  PELLEGRINI, CARLOS 1345
# 1                  Arroyo        800.0       848.0               ARROYO 848
# 1                  Arroyo        900.0       932.0               ARROYO 932
# 1                  Arroyo        900.0       932.0               ARROYO 932
#
#        ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# ...

# %%
data.iloc[1]
# Out:
# long                                  -58.381532
# lat                                   -34.592319
# nro_registro                               30887
# tipo_activ                                Lineal
# comuna                                         1
# manzana                                      NaN
# calle_nombre                   Pellegrini Carlos
# calle_altura                              1300.0
# calle_chapa                               1345.0
# direccion_normalizada    PELLEGRINI, CARLOS 1345
# ubicacion                                 Exacta
# nombre_cientifico             Peltophorum dubium
# ancho_acera                                  4.5
# estado_plantera                          Ocupada
# ubicacion_plantera                       Regular
# nivel_plantera                           Elevada
# diametro_altura_pecho                        6.0
# altura_arbol                                 5.0
# Name: 1, dtype: object
